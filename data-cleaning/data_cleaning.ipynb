# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\sakib\appdata\local\programs\python\python313\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sakib\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sakib\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sakib\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sakib\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sakib\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\sakib\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install datetime
# Out:
# Requirement already satisfied: datetime in c:\users\sakib\appdata\local\programs\python\python313\lib\site-packages (5.5)
# Requirement already satisfied: zope.interface in c:\users\sakib\appdata\local\programs\python\python313\lib\site-packages (from datetime) (7.2)
# Requirement already satisfied: pytz in c:\users\sakib\appdata\local\programs\python\python313\lib\site-packages (from datetime) (2025.2)
# Requirement already satisfied: setuptools in c:\users\sakib\appdata\local\programs\python\python313\lib\site-packages (from zope.interface->datetime) (80.9.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# Load the dataset
df = pd.read_csv("uncleaned_dataset (1).csv")

# %%
df
# Out:
#        Name     Age  Gender   Income      JoinDate Subscription  \
# 0     David  twenty     NaN    90576    2020-02-16          NaN
# 1     David     NaN     NaN    64288    2018-02-21          NaN
# 2       Bob  twenty     NaN    39551    2019-04-17          NaN
# 3   Charlie  twenty  Female  unknown    2021-04-08          NaN
# 4     Alice      -5     NaN  unknown    2023-09-18          NaN
# ..      ...     ...     ...      ...           ...          ...
# 95      Bob      37       F    35850  invalid_date          NaN
# 96    David  twenty       m    98631    2020-12-15            Y
# 97      Bob      -5       F  unknown    2023-05-18            Y
# 98      Eva     NaN       m      NaN    2021-11-05          NaN
# 99      Eva      57       F    80658           NaN            0
#
#               Email Country Feedback
# 0               NaN     USA      NaN
# 1               NaN  Canada      NaN
# 2               NaN     NaN      NaN
# 3               NaN   India      Bad
# 4               NaN   India      NaN
# ..              ...     ...      ...
# 95              NaN     USA     Good
# 96  user26@mail.com      UK  Average
# 97  user14@mail.com  Canada      NaN
# 98  user45@mail.com      UK     Good
# 99              NaN   India  Average
#
# [100 rows x 9 columns]

# %%
# Name cleanup
df = df.dropna(subset=['Name'])

# %%
df
# Out:
#        Name     Age  Gender   Income      JoinDate Subscription  \
# 0     David  twenty     NaN    90576    2020-02-16          NaN
# 1     David     NaN     NaN    64288    2018-02-21          NaN
# 2       Bob  twenty     NaN    39551    2019-04-17          NaN
# 3   Charlie  twenty  Female  unknown    2021-04-08          NaN
# 4     Alice      -5     NaN  unknown    2023-09-18          NaN
# ..      ...     ...     ...      ...           ...          ...
# 95      Bob      37       F    35850  invalid_date          NaN
# 96    David  twenty       m    98631    2020-12-15            Y
# 97      Bob      -5       F  unknown    2023-05-18            Y
# 98      Eva     NaN       m      NaN    2021-11-05          NaN
# 99      Eva      57       F    80658           NaN            0
#
#               Email Country Feedback
# 0               NaN     USA      NaN
# 1               NaN  Canada      NaN
# 2               NaN     NaN      NaN
# 3               NaN   India      Bad
# 4               NaN   India      NaN
# ..              ...     ...      ...
# 95              NaN     USA     Good
# 96  user26@mail.com      UK  Average
# 97  user14@mail.com  Canada      NaN
# 98  user45@mail.com      UK     Good
# 99              NaN   India  Average
#
# [86 rows x 9 columns]

# %%
# 1. Clean Age column
df['Age'] = pd.to_numeric(df['Age'], errors='coerce') 
df.loc[df['Age'] < 0, 'Age'] = np.nan
df['Age'] = df['Age'].fillna(df['Age'].median())
# Out:
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\3454338088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\3454338088.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df
# Out:
#        Name   Age  Gender   Income      JoinDate Subscription  \
# 0     David  20.0     NaN    90576    2020-02-16          NaN
# 1     David  20.0     NaN    64288    2018-02-21          NaN
# 2       Bob  20.0     NaN    39551    2019-04-17          NaN
# 3   Charlie  20.0  Female  unknown    2021-04-08          NaN
# 4     Alice  20.0     NaN  unknown    2023-09-18          NaN
# ..      ...   ...     ...      ...           ...          ...
# 95      Bob  37.0       F    35850  invalid_date          NaN
# 96    David  20.0       m    98631    2020-12-15            Y
# 97      Bob  20.0       F  unknown    2023-05-18            Y
# 98      Eva  20.0       m      NaN    2021-11-05          NaN
# 99      Eva  57.0       F    80658           NaN            0
#
#               Email Country Feedback
# 0               NaN     USA      NaN
# 1               NaN  Canada      NaN
# 2               NaN     NaN      NaN
# 3               NaN   India      Bad
# 4               NaN   India      NaN
# ..              ...     ...      ...
# 95              NaN     USA     Good
# 96  user26@mail.com      UK  Average
# 97  user14@mail.com  Canada      NaN
# 98  user45@mail.com      UK     Good
# 99              NaN   India  Average
#
# [86 rows x 9 columns]

# %%
# 2. Standardize Gender
df['Gender'] = df['Gender'].str.strip().str.capitalize()
df['Gender'] = df['Gender'].replace({'M': 'Male', 'F': 'Female'})
df['Gender'] = df['Gender'].fillna('Unknown')
# Out:
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\1326560358.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].str.strip().str.capitalize()
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\1326560358.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].replace({'M': 'Male', 'F': 'Female'})
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\1326560358.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].fillna('Unknown')

# %%
df
# Out:
#        Name   Age   Gender   Income      JoinDate Subscription  \
# 0     David  20.0  Unknown    90576    2020-02-16          NaN
# 1     David  20.0  Unknown    64288    2018-02-21          NaN
# 2       Bob  20.0  Unknown    39551    2019-04-17          NaN
# 3   Charlie  20.0   Female  unknown    2021-04-08          NaN
# 4     Alice  20.0  Unknown  unknown    2023-09-18          NaN
# ..      ...   ...      ...      ...           ...          ...
# 95      Bob  37.0   Female    35850  invalid_date          NaN
# 96    David  20.0     Male    98631    2020-12-15            Y
# 97      Bob  20.0   Female  unknown    2023-05-18            Y
# 98      Eva  20.0     Male      NaN    2021-11-05          NaN
# 99      Eva  57.0   Female    80658           NaN            0
#
#               Email Country Feedback
# 0               NaN     USA      NaN
# 1               NaN  Canada      NaN
# 2               NaN     NaN      NaN
# 3               NaN   India      Bad
# 4               NaN   India      NaN
# ..              ...     ...      ...
# 95              NaN     USA     Good
# 96  user26@mail.com      UK  Average
# 97  user14@mail.com  Canada      NaN
# 98  user45@mail.com      UK     Good
# 99              NaN   India  Average
#
# [86 rows x 9 columns]

# %%
# 3. Clean Income
df['Income'] = pd.to_numeric(df['Income'], errors='coerce')
df.loc[df['Income'] < 0, 'Income'] = np.nan
df['Income'] = df['Income'].fillna(df['Income'].median())
# Out:
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\1021854766.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Income'] = pd.to_numeric(df['Income'], errors='coerce')
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\1021854766.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Income'] = df['Income'].fillna(df['Income'].median())

# %%
df
# Out:
#        Name   Age   Gender   Income      JoinDate Subscription  \
# 0     David  20.0  Unknown  90576.0    2020-02-16          NaN
# 1     David  20.0  Unknown  64288.0    2018-02-21          NaN
# 2       Bob  20.0  Unknown  39551.0    2019-04-17          NaN
# 3   Charlie  20.0   Female  57072.0    2021-04-08          NaN
# 4     Alice  20.0  Unknown  57072.0    2023-09-18          NaN
# ..      ...   ...      ...      ...           ...          ...
# 95      Bob  37.0   Female  35850.0  invalid_date          NaN
# 96    David  20.0     Male  98631.0    2020-12-15            Y
# 97      Bob  20.0   Female  57072.0    2023-05-18            Y
# 98      Eva  20.0     Male  57072.0    2021-11-05          NaN
# 99      Eva  57.0   Female  80658.0           NaN            0
#
#               Email Country Feedback
# 0               NaN     USA      NaN
# 1               NaN  Canada      NaN
# 2               NaN     NaN      NaN
# 3               NaN   India      Bad
# 4               NaN   India      NaN
# ..              ...     ...      ...
# 95              NaN     USA     Good
# 96  user26@mail.com      UK  Average
# 97  user14@mail.com  Canada      NaN
# 98  user45@mail.com      UK     Good
# 99              NaN   India  Average
#
# [86 rows x 9 columns]

# %%
# 4. Fix JoinDate
df['JoinDate'] = pd.to_datetime(df['JoinDate'], errors='coerce')
df['JoinDate'] = df['JoinDate'].fillna(method='ffill')
# Out:
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\427651970.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JoinDate'] = pd.to_datetime(df['JoinDate'], errors='coerce')
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\427651970.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['JoinDate'] = df['JoinDate'].fillna(method='ffill')
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\427651970.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JoinDate'] = df['JoinDate'].fillna(method='ffill')

# %%
df
# Out:
#        Name   Age   Gender   Income   JoinDate Subscription            Email  \
# 0     David  20.0  Unknown  90576.0 2020-02-16          NaN              NaN
# 1     David  20.0  Unknown  64288.0 2018-02-21          NaN              NaN
# 2       Bob  20.0  Unknown  39551.0 2019-04-17          NaN              NaN
# 3   Charlie  20.0   Female  57072.0 2021-04-08          NaN              NaN
# 4     Alice  20.0  Unknown  57072.0 2023-09-18          NaN              NaN
# ..      ...   ...      ...      ...        ...          ...              ...
# 95      Bob  37.0   Female  35850.0 2023-12-13          NaN              NaN
# 96    David  20.0     Male  98631.0 2020-12-15            Y  user26@mail.com
# 97      Bob  20.0   Female  57072.0 2023-05-18            Y  user14@mail.com
# 98      Eva  20.0     Male  57072.0 2021-11-05          NaN  user45@mail.com
# 99      Eva  57.0   Female  80658.0 2021-11-05            0              NaN
#
#    Country Feedback
# 0      USA      NaN
# 1   Canada      NaN
# 2      NaN      NaN
# 3    India      Bad
# 4    India      NaN
# ..     ...      ...
# 95     USA     Good
# 96      UK  Average
# 97  Canada      NaN
# 98      UK     Good
# 99   India  Average
#
# [86 rows x 9 columns]

# %%
# 5. Clean Subscription column
df['Subscription'] = df['Subscription'].replace({
    'Y': 'Yes', 'N': 'No', '1': 'Yes', '0': 'No'
})
df['Subscription'] = df['Subscription'].fillna('No')
# Out:
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\2025495984.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Subscription'] = df['Subscription'].replace({
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\2025495984.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Subscription'] = df['Subscription'].fillna('No')

# %%
df
# Out:
#        Name   Age   Gender   Income   JoinDate Subscription            Email  \
# 0     David  20.0  Unknown  90576.0 2020-02-16           No              NaN
# 1     David  20.0  Unknown  64288.0 2018-02-21           No              NaN
# 2       Bob  20.0  Unknown  39551.0 2019-04-17           No              NaN
# 3   Charlie  20.0   Female  57072.0 2021-04-08           No              NaN
# 4     Alice  20.0  Unknown  57072.0 2023-09-18           No              NaN
# ..      ...   ...      ...      ...        ...          ...              ...
# 95      Bob  37.0   Female  35850.0 2023-12-13           No              NaN
# 96    David  20.0     Male  98631.0 2020-12-15          Yes  user26@mail.com
# 97      Bob  20.0   Female  57072.0 2023-05-18          Yes  user14@mail.com
# 98      Eva  20.0     Male  57072.0 2021-11-05           No  user45@mail.com
# 99      Eva  57.0   Female  80658.0 2021-11-05           No              NaN
#
#    Country Feedback
# 0      USA      NaN
# 1   Canada      NaN
# 2      NaN      NaN
# 3    India      Bad
# 4    India      NaN
# ..     ...      ...
# 95     USA     Good
# 96      UK  Average
# 97  Canada      NaN
# 98      UK     Good
# 99   India  Average
#
# [86 rows x 9 columns]

# %%
# 6. Clean Email (fill with placeholder)
df['Email'] = df['Email'].fillna('unknown@example.com')
# Out:
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\2604594510.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Email'] = df['Email'].fillna('unknown@example.com')

# %%
# 6. Clean Email (fill with placeholder)
df['Email'] = df['Email'].fillna('unknown@example.com')

# %%
df
# Out:
#        Name   Age   Gender   Income   JoinDate Subscription  \
# 0     David  20.0  Unknown  90576.0 2020-02-16           No
# 1     David  20.0  Unknown  64288.0 2018-02-21           No
# 2       Bob  20.0  Unknown  39551.0 2019-04-17           No
# 3   Charlie  20.0   Female  57072.0 2021-04-08           No
# 4     Alice  20.0  Unknown  57072.0 2023-09-18           No
# ..      ...   ...      ...      ...        ...          ...
# 95      Bob  37.0   Female  35850.0 2023-12-13           No
# 96    David  20.0     Male  98631.0 2020-12-15          Yes
# 97      Bob  20.0   Female  57072.0 2023-05-18          Yes
# 98      Eva  20.0     Male  57072.0 2021-11-05           No
# 99      Eva  57.0   Female  80658.0 2021-11-05           No
#
#                   Email Country Feedback
# 0   unknown@example.com     USA      NaN
# 1   unknown@example.com  Canada      NaN
# 2   unknown@example.com     NaN      NaN
# 3   unknown@example.com   India      Bad
# 4   unknown@example.com   India      NaN
# ..                  ...     ...      ...
# 95  unknown@example.com     USA     Good
# 96      user26@mail.com      UK  Average
# 97      user14@mail.com  Canada      NaN
# 98      user45@mail.com      UK     Good
# 99  unknown@example.com   India  Average
#
# [86 rows x 9 columns]

# %%
# 7. Clean Country
df['Country'] = df['Country'].replace('', np.nan)
df['Country'] = df['Country'].fillna('Unknown')
# Out:
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\1768248927.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country'] = df['Country'].replace('', np.nan)
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\1768248927.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country'] = df['Country'].fillna('Unknown')

# %%
df
# Out:
#        Name   Age   Gender   Income   JoinDate Subscription  \
# 0     David  20.0  Unknown  90576.0 2020-02-16           No
# 1     David  20.0  Unknown  64288.0 2018-02-21           No
# 2       Bob  20.0  Unknown  39551.0 2019-04-17           No
# 3   Charlie  20.0   Female  57072.0 2021-04-08           No
# 4     Alice  20.0  Unknown  57072.0 2023-09-18           No
# ..      ...   ...      ...      ...        ...          ...
# 95      Bob  37.0   Female  35850.0 2023-12-13           No
# 96    David  20.0     Male  98631.0 2020-12-15          Yes
# 97      Bob  20.0   Female  57072.0 2023-05-18          Yes
# 98      Eva  20.0     Male  57072.0 2021-11-05           No
# 99      Eva  57.0   Female  80658.0 2021-11-05           No
#
#                   Email  Country Feedback
# 0   unknown@example.com      USA      NaN
# 1   unknown@example.com   Canada      NaN
# 2   unknown@example.com  Unknown      NaN
# 3   unknown@example.com    India      Bad
# 4   unknown@example.com    India      NaN
# ..                  ...      ...      ...
# 95  unknown@example.com      USA     Good
# 96      user26@mail.com       UK  Average
# 97      user14@mail.com   Canada      NaN
# 98      user45@mail.com       UK     Good
# 99  unknown@example.com    India  Average
#
# [86 rows x 9 columns]

# %%
# 8. Clean Feedback (fill blanks or NaNs with 'No Feedback')
df['Feedback'] = df['Feedback'].replace('', np.nan)
df['Feedback'] = df['Feedback'].fillna('No Feedback')
# Out:
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\319534440.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Feedback'] = df['Feedback'].replace('', np.nan)
# C:\Users\sakib\AppData\Local\Temp\ipykernel_12128\319534440.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Feedback'] = df['Feedback'].fillna('No Feedback')

# %%
df
# Out:
#        Name   Age   Gender   Income   JoinDate Subscription  \
# 0     David  20.0  Unknown  90576.0 2020-02-16           No
# 1     David  20.0  Unknown  64288.0 2018-02-21           No
# 2       Bob  20.0  Unknown  39551.0 2019-04-17           No
# 3   Charlie  20.0   Female  57072.0 2021-04-08           No
# 4     Alice  20.0  Unknown  57072.0 2023-09-18           No
# ..      ...   ...      ...      ...        ...          ...
# 95      Bob  37.0   Female  35850.0 2023-12-13           No
# 96    David  20.0     Male  98631.0 2020-12-15          Yes
# 97      Bob  20.0   Female  57072.0 2023-05-18          Yes
# 98      Eva  20.0     Male  57072.0 2021-11-05           No
# 99      Eva  57.0   Female  80658.0 2021-11-05           No
#
#                   Email  Country     Feedback
# 0   unknown@example.com      USA  No Feedback
# 1   unknown@example.com   Canada  No Feedback
# 2   unknown@example.com  Unknown  No Feedback
# 3   unknown@example.com    India          Bad
# 4   unknown@example.com    India  No Feedback
# ..                  ...      ...          ...
# 95  unknown@example.com      USA         Good
# 96      user26@mail.com       UK      Average
# 97      user14@mail.com   Canada  No Feedback
# 98      user45@mail.com       UK         Good
# 99  unknown@example.com    India      Average
#
# [86 rows x 9 columns]

# %%
# Save cleaned dataset
df.to_csv("cleaned_dataset.csv", index=False)
